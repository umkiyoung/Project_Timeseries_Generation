# %%
import matplotlib.pyplot as plt
from dataloader import DataloaderHandler

# load dataloader handler
dlh = DataloaderHandler(batch_size=128,
                        shuffle=True,
                        drop_last=True)

# %%
# sine dataloader
sine_dl = dlh.sine_dataloader(sample_n=10000,
                              seq_len=24,
                              feature_n=5)
X = next(iter(sine_dl))
print(X)
print(X.shape)

# visualize
plt.figure()
plt.plot(X[0])
plt.show()
# Out:
# tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0763, 0.0520, 0.0609, 0.0727, 0.0839],
#          [0.1518, 0.1038, 0.1213, 0.1448, 0.1670],
#          ...,
#          [1.0000, 0.9389, 0.9661, 0.9977, 0.9856],
#          [0.9981, 0.9703, 0.9847, 1.0000, 0.9682],
#          [0.9909, 1.0000, 1.0000, 0.9973, 0.9443]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0597, 0.0442, 0.1024, 0.0462, 0.0721],
#          [0.1190, 0.0883, 0.2031, 0.0924, 0.1435],
#          ...,
#          [0.9623, 0.9154, 0.8632, 0.9216, 0.9955],
#          [0.9827, 0.9578, 0.8086, 0.9611, 1.0000],
#          [1.0000, 1.0000, 0.7459, 1.0000, 0.9997]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0436, 0.0453, 0.1043, 0.0528, 0.0805],
#          [0.0872, 0.0906, 0.2068, 0.1054, 0.1604],
#          ...,
#          [0.9133, 0.9188, 0.8445, 0.9422, 0.9946],
#          [0.9566, 0.9596, 0.7858, 0.9720, 0.9829],
#          [1.0000, 1.0000, 0.7189, 1.0000, 0.9650]],
#
#         ...,
#
#         [[0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.1001, 0.0628, 0.0437, 0.0785, 0.0560],
#          [0.1987, 0.1252, 0.0873, 0.1564, 0.1118],
#          ...,
#          [0.8878, 0.9713, 0.9137, 0.9975, 0.9525],
#          [0.8390, 0.9874, 0.9568, 0.9890, 0.9775],
#          [0.7822, 1.0000, 1.0000, 0.9744, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0438, 0.0494, 0.0529, 0.1048, 0.0476],
#          [0.0875, 0.0987, 0.1055, 0.2077, 0.0951],
#          ...,
#          [0.9138, 0.9312, 0.9418, 0.8467, 0.9268],
#          [0.9569, 0.9662, 0.9718, 0.7885, 0.9639],
#          [1.0000, 1.0000, 1.0000, 0.7221, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#          [0.0790, 0.0470, 0.0948, 0.0588, 0.0929],
#          [0.1572, 0.0939, 0.1884, 0.1172, 0.1846],
#          ...,
#          [0.9979, 0.9239, 0.9261, 0.9589, 0.9416],
#          [0.9899, 0.9623, 0.8871, 0.9809, 0.9072],
#          [0.9759, 1.0000, 0.8404, 1.0000, 0.8652]]])
# torch.Size([128, 24, 5])

# %%
# synthetic time-series data
syn_dl = dlh.synthetic_dataloader(sample_n=10000,
                                  seq_len=24,
                                  freq=1,
                                  noise_level=0.1,
                                  trend=True)

X = next(iter(syn_dl))
print(X)
print(X.shape)

# visualize
plt.figure()
plt.plot(X[0])
plt.show()
# Out:
# tensor([[0.2199, 0.3598, 0.4885,  ..., 0.4276, 0.5994, 0.7876],
#         [0.1221, 0.3927, 0.5772,  ..., 0.3407, 0.5461, 0.7336],
#         [0.1803, 0.2310, 0.6749,  ..., 0.3600, 0.5593, 0.7514],
#         ...,
#         [0.1549, 0.4112, 0.5265,  ..., 0.4065, 0.6500, 0.8260],
#         [0.2015, 0.3310, 0.5659,  ..., 0.3885, 0.5339, 0.8080],
#         [0.3120, 0.3345, 0.6241,  ..., 0.4838, 0.6495, 0.8228]])
# torch.Size([128, 24])

# %%
# stock real data
stock_dl = dlh.stock_dataloader(symbols=["AAPL","GOOG"],
                                sdate="2010",
                                window=24)

X = next(iter(stock_dl))
print(X)
print(X.shape)

# visualize
plt.figure()
plt.plot(X[0])
plt.show()
# Out:
# tensor([[[0.3257, 0.6602],
#          [0.7261, 0.5806],
#          [1.0000, 0.7683],
#          ...,
#          [0.6762, 0.1838],
#          [0.5594, 0.2113],
#          [0.2874, 0.0000]],
#
#         [[0.0693, 0.0246],
#          [0.0538, 0.0000],
#          [0.0598, 0.2468],
#          ...,
#          [1.0000, 0.1924],
#          [0.9252, 0.2740],
#          [0.9104, 0.2003]],
#
#         [[0.3650, 0.4320],
#          [0.3263, 0.3585],
#          [0.1784, 0.1843],
#          ...,
#          [0.9680, 0.8800],
#          [0.9814, 0.9280],
#          [0.9537, 0.8375]],
#
#         ...,
#
#         [[0.2091, 0.7019],
#          [0.4094, 0.8600],
#          [0.4904, 0.7861],
#          ...,
#          [0.3168, 0.3592],
#          [0.2697, 0.2215],
#          [0.0000, 0.0000]],
#
#         [[0.0000,    nan],
#          [0.2840,    nan],
#          [0.4991,    nan],
#          ...,
#          [0.3790,    nan],
#          [0.4102,    nan],
#          [0.1593,    nan]],
#
#         [[0.8739,    nan],
#          [0.9172,    nan],
#          [1.0000,    nan],
#          ...,
#          [0.6126,    nan],
#          [0.5073,    nan],
#          [0.5484,    nan]]])
# torch.Size([128, 24, 2])
